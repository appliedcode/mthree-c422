# %% [markdown]
# 1. Genetic Algorithm Lab: Solving the Maximum Ones Problem
# We'll use a simple genetic algorithm to maximize the number of "1"s in a binary string.

# %%
# 1. Genetic Algorithm Lab: Solving the Maximum Ones Problem
# We'll use a simple genetic algorithm to maximize the number of "1"s in a binary string.

# Step 1: Imports and Parameters
import numpy as np
import random

# %%
# Step 2: GA Functions
def create_individual(length):
    # Random binary individual
    return np.random.randint(2, size=length)

def fitness(individual):
    # Objective: maximize number of 1s
    return sum(individual)

def mutate(individual, mutation_rate=0.01):
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] = 1 - individual[i]
    return individual

def crossover(parent1, parent2):
    point = random.randint(1, len(parent1)-1)
    child1 = np.concatenate([parent1[:point], parent2[point:]])
    child2 = np.concatenate([parent2[:point], parent1[point:]])
    return child1, child2

# %%
def genetic_algorithm(population_size=10, chromosome_length=8, generations=20, mutation_rate=0.01):
    print("hellow")
    population = [create_individual(chromosome_length) for _ in range(population_size)]

    for g in range(generations):
        scored = sorted(
            [(fitness(ind), ind) for ind in population],
            key=lambda pair: pair[0],
            reverse=True
        )
        print(f"Gen {g} | Best: {scored[0][0]} | Avg: {np.mean([f for f,_ in scored])}")

        next_gen = [scored[0][1], scored[1][1]]  # Elite selection

        while len(next_gen) < population_size:
            parents = random.sample(scored[:5], 2)
            c1, c2 = crossover(parents[0][1], parents[1][1])
            next_gen.append(mutate(c1.copy(), mutation_rate))
            if len(next_gen) < population_size:
                next_gen.append(mutate(c2.copy(), mutation_rate))

        population = next_gen

    print("Best individual:", scored[0][1], "with fitness:", scored[0][0])
genetic_algorithm()
# Out:
# hellow
# Gen 0 | Best: 7 | Avg: 3.9
# Gen 1 | Best: 7 | Avg: 5.0
# Gen 2 | Best: 7 | Avg: 6.1
# Gen 3 | Best: 7 | Avg: 6.9
# Gen 4 | Best: 7 | Avg: 7.0
# Gen 5 | Best: 7 | Avg: 6.9
# Gen 6 | Best: 7 | Avg: 7.0
# Gen 7 | Best: 7 | Avg: 7.0
# Gen 8 | Best: 7 | Avg: 7.0
# Gen 9 | Best: 7 | Avg: 7.0
# Gen 10 | Best: 7 | Avg: 7.0
# Gen 11 | Best: 7 | Avg: 6.7
# Gen 12 | Best: 7 | Avg: 7.0
# Gen 13 | Best: 7 | Avg: 7.0
# Gen 14 | Best: 7 | Avg: 7.0
# Gen 15 | Best: 7 | Avg: 7.0
# Gen 16 | Best: 7 | Avg: 7.0
# Gen 17 | Best: 8 | Avg: 6.9
# Gen 18 | Best: 8 | Avg: 7.2
# Gen 19 | Best: 8 | Avg: 7.7
# Best individual: [1 1 1 1 1 1 1 1] with fitness: 8

# %% [markdown]
# ## Extension:
# - Try increasing chromosome_length or population_size.
#
# - Modify the fitness function to solve other problems (e.g., string matching).

# %%
# 2. Artificial Neural Network Lab: Iris Dataset Classification
# We'll use TensorFlow/Keras to build and train a simple neural network to classify iris species based on flower measurements.

# Step 1: Imports
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

# %%
# Step 2: Data Preparation
# Load data and prepare splits
iris = load_iris()
X = iris.data
y = iris.target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)

# %%
# Step 3: Build and Train the Neural Network
model = keras.Sequential([
    keras.layers.Dense(8, activation='relu', input_shape=(4,)),
    keras.layers.Dense(6, activation='relu'),
    keras.layers.Dense(3, activation='softmax') # 3 classes
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.5259 - loss: 1.0544 - val_accuracy: 0.5526 - val_loss: 1.0262
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4946 - loss: 1.0587 - val_accuracy: 0.5526 - val_loss: 1.0092
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4811 - loss: 1.0630 - val_accuracy: 0.5526 - val_loss: 0.9927
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5637 - loss: 1.0068 - val_accuracy: 0.5526 - val_loss: 0.9768
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5865 - loss: 0.9956 - val_accuracy: 0.5526 - val_loss: 0.9611
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5723 - loss: 0.9828 - val_accuracy: 0.5789 - val_loss: 0.9458
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5932 - loss: 0.9597 - val_accuracy: 0.6053 - val_loss: 0.9312
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5863 - loss: 0.9587 - val_accuracy: 0.6053 - val_loss: 0.9171
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5951 - loss: 0.9362 - val_accuracy: 0.6053 - val_loss: 0.9032
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6128 - loss: 0.9212 - val_accuracy: 0.6579 - val_loss: 0.8894
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5935 - loss: 0.9319 - val_accuracy: 0.6579 - val_loss: 0.8757
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5747 - loss: 0.9247 - val_accuracy: 0.6579 - val_loss: 0.8621
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6167 - loss: 0.8880 - val_accuracy: 0.6842 - val_loss: 0.8483
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6484 - loss: 0.8674 - val_accuracy: 0.7105 - val_loss: 0.8347
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6463 - loss: 0.8509 - val_accuracy: 0.7105 - val_loss: 0.8211
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6408 - loss: 0.8725 - val_accuracy: 0.7368 - val_loss: 0.8076
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6600 - loss: 0.8586 - val_accuracy: 0.7632 - val_loss: 0.7942
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6957 - loss: 0.8267 - val_accuracy: 0.7895 - val_loss: 0.7808
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7341 - loss: 0.8036 - val_accuracy: 0.7895 - val_loss: 0.7675
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7460 - loss: 0.7957 - val_accuracy: 0.7895 - val_loss: 0.7544
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7360 - loss: 0.7734 - val_accuracy: 0.7895 - val_loss: 0.7412
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7479 - loss: 0.7851 - val_accuracy: 0.7895 - val_loss: 0.7281
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7327 - loss: 0.7826 - val_accuracy: 0.7895 - val_loss: 0.7152
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7655 - loss: 0.7525 - val_accuracy: 0.7895 - val_loss: 0.7022
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7930 - loss: 0.7281 - val_accuracy: 0.7895 - val_loss: 0.6891
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7826 - loss: 0.7195 - val_accuracy: 0.7895 - val_loss: 0.6763
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7862 - loss: 0.6997 - val_accuracy: 0.7895 - val_loss: 0.6638
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8054 - loss: 0.6847 - val_accuracy: 0.7895 - val_loss: 0.6515
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7979 - loss: 0.6760 - val_accuracy: 0.7895 - val_loss: 0.6394
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7979 - loss: 0.6791 - val_accuracy: 0.7895 - val_loss: 0.6274
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8167 - loss: 0.6553 - val_accuracy: 0.7895 - val_loss: 0.6156
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8062 - loss: 0.6529 - val_accuracy: 0.7895 - val_loss: 0.6040
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7906 - loss: 0.6387 - val_accuracy: 0.7895 - val_loss: 0.5926
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8577 - loss: 0.5906 - val_accuracy: 0.7895 - val_loss: 0.5817
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8296 - loss: 0.6129 - val_accuracy: 0.7895 - val_loss: 0.5712
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8359 - loss: 0.5966 - val_accuracy: 0.7895 - val_loss: 0.5610
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8359 - loss: 0.5947 - val_accuracy: 0.7895 - val_loss: 0.5512
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8269 - loss: 0.5864 - val_accuracy: 0.7895 - val_loss: 0.5416
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8269 - loss: 0.5772 - val_accuracy: 0.7895 - val_loss: 0.5323
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8217 - loss: 0.5866 - val_accuracy: 0.8158 - val_loss: 0.5233
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8113 - loss: 0.5697 - val_accuracy: 0.8158 - val_loss: 0.5144
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8478 - loss: 0.5374 - val_accuracy: 0.8158 - val_loss: 0.5057
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8405 - loss: 0.5544 - val_accuracy: 0.8158 - val_loss: 0.4974
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8457 - loss: 0.5301 - val_accuracy: 0.8158 - val_loss: 0.4891
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8467 - loss: 0.5125 - val_accuracy: 0.8158 - val_loss: 0.4812
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8315 - loss: 0.5399 - val_accuracy: 0.8158 - val_loss: 0.4736
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8518 - loss: 0.4984 - val_accuracy: 0.8158 - val_loss: 0.4663
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8643 - loss: 0.4915 - val_accuracy: 0.8158 - val_loss: 0.4592
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8034 - loss: 0.5368 - val_accuracy: 0.8158 - val_loss: 0.4523
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8138 - loss: 0.5176 - val_accuracy: 0.8158 - val_loss: 0.4457

# %%
# Step 4: Evaluate and Visualize Results
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', test_acc)

import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8251 - loss: 0.4392
#
# Test accuracy: 0.8157894611358643

# %% [markdown]
# ### Extension and Discussion:
# - Experiment with more or fewer layers/neurons, different activation functions.
#
# - Visualize the loss curve: plt.plot(history.history['loss'])
#
# - Try predicting the species of a new iris measurement by:
#   ```python
#   example = scaler.transform([[5.1, 3.5, 1.4, 0.2]])
# print(model.predict(example))
# ```

# %%
plt.plot(history.history['loss'])

# %%
example = scaler.transform([[5.1, 3.5, 1.4, 0.2]])
print(model.predict(example))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# [[0.90112376 0.05568539 0.0431909 ]]
