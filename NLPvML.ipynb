# %% [markdown]
# <a href="https://colab.research.google.com/github/appliedcode/mthree-c422/blob/mthree-c422-Prashanth/NLPvML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RuleBased - NLP

# %%
import re

text = "Please schedule a meeting with Prem tomorrow at 9 AM."

if re.search(r'\bplease\b', text.lower()) and re.search(r'\b(schedule|book|arrange)\b', text.lower()):
    print("Detected Intent: Set Meeting")
else:
    print("Intent not recognized.")
# Out:
# Detected Intent: Set Meeting

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from transformers import pipeline, logging
logging.set_verbosity_error()

# Load zero-shot classification pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# Input text
text = "Please schedule a meeting with John tomorrow at 10 AM."
labels = ["Set Meeting", "Cancel Meeting", "Weather Query"]

# Predict intent
result = classifier(text, labels)
print("Predicted Intent:", result['labels'][0])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Predicted Intent: Set Meeting

# %%
import re

def detect_cancel_meeting(text):
    text = text.lower()
    if re.search(r'\bcancel\b', text) and re.search(r'\bmeeting\b', text):
        print("Detected Intent: Cancel Meeting")
    else:
        print("Intent not recognized.")

# Test sentence
test_text = "Can you please cancel my meeting with Alice at 2 PM?"
detect_cancel_meeting(test_text)
# Out:
# Detected Intent: Cancel Meeting

# %%
from transformers import pipeline
import warnings
warnings.filterwarnings("ignore")

# Load pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# Input text and labels
text = "Will it rain tomorrow in New York?"
labels = ["Set Meeting", "Cancel Meeting", "Weather Query"]

# Predict intent
result = classifier(text, labels)
print("Predicted Intent:", result['labels'][0])
# Out:
# Predicted Intent: Weather Query

# %%
# New sentence and labels
text = "I'd like to order a large pepperoni pizza for dinner."
labels = ["Set Meeting", "Cancel Meeting", "Weather Query", "Order Food"]

# Predict intent
result = classifier(text, labels)
print("Predicted Intent:", result['labels'][0])
# Out:
# Predicted Intent: Order Food

# %%
text = "Please book a meeting with Sarah next Monday."
if re.search(r'\bplease\b', text.lower()) and re.search(r'\b(schedule|book|arrange)\b', text.lower()):
    print("Rule-based Detected Intent: Set Meeting")
else:
    print("Rule-based: Intent not recognized.")
# Out:
# Rule-based Detected Intent: Set Meeting
