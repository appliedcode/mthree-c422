# %% [markdown]
# <a href="https://colab.research.google.com/github/appliedcode/mthree-c422/blob/main/Exercises/day-14/Social_Economic_Impact/Social_Economic_Impact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab Exercise: Social and Economic Impact of AI
#
# ## Objective
#
# To explore and analyze AI’s effects on jobs, inequality, ethical dilemmas, public perception, and trust through data-driven and discussion activities.
#
# ***
#
# ## Part 1: Impact of AI on Jobs and Economic Inequality

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Synthetic dataset: Job automation risk vs wage distribution
np.random.seed(0)
n = 500

data_jobs = pd.DataFrame({
    "Occupation": [f"Job_{i}" for i in range(1, n+1)],
    "Automation_Risk": np.random.beta(2, 5, n),  # Risk score between 0 (low) and 1 (high)
    "Median_Wage": np.random.normal(50000, 15000, n)  # USD annual wages
})

# Visualize relationship between automation risk and wages
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Automation_Risk', y='Median_Wage', data=data_jobs)
plt.title('Job Automation Risk vs Median Wage')
plt.xlabel('Automation Risk (0=Low, 1=High)')
plt.ylabel('Median Annual Wage (USD)')
plt.show()

# %% [markdown]
# ***
#
# ## Part 2: Ethical Dilemmas Exploration - Case Study Examples

# %%
# Three ethical dilemma examples for discussion

ethical_dilemmas = {
    "Surveillance": "AI-powered mass surveillance like China's social credit system raises privacy and freedom concerns.",
    "Autonomous Systems": "Ethical questions about responsibility when self-driving cars cause accidents.",
    "Deepfakes": "AI-generated fake videos undermine trust in media and can cause misinformation."
}

for topic, scenario in ethical_dilemmas.items():
    print(f"--- {topic} ---\n{scenario}\n")

# Task:
# Reflect on one ethical dilemma.
# Propose policy or technical safeguards that could mitigate harm in that scenario.
# Out:
# --- Surveillance ---
# AI-powered mass surveillance like China's social credit system raises privacy and freedom concerns.
#
# --- Autonomous Systems ---
# Ethical questions about responsibility when self-driving cars cause accidents.
#
# --- Deepfakes ---
# AI-generated fake videos undermine trust in media and can cause misinformation.

# %% [markdown]
# ***
#
# ## Part 3: Public Perception and Societal Trust in AI

# %%
# Synthetic survey data on AI public perception
data_perception = pd.DataFrame({
    "Trust": ["Trust AI", "Neutral", "Distrust AI"],
    "Percentage": [35, 25, 40]
})

# Plot public perception pie chart
plt.figure(figsize=(6, 6))
plt.pie(data_perception["Percentage"], labels=data_perception["Trust"], autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ffcc99','#ff6666'])
plt.title('Public Perception of AI')
plt.show()

# Task:
# 1. Interpret the level of trust in AI from the pie chart.
# 2. Discuss factors that build or erode societal trust.
# 3. Suggest ways AI developers and policymakers can increase transparency and trust.
