# %%
import pandas as pd

# %%
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 1, figsize = (4,5))
axs[0].scatter(X['Mileage'], y, color ='b', marker = '+')
axs[0].set_title('Mileage vs Sell Price')
axs[1].scatter(X['Age(yrs)'], y, color = 'r', marker = '+')
axs[1].set_title('Age vs Sell Price($)')
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
len(X_train)
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([26172.69756069, 25656.1655798 , 23073.50567534, 27464.02751292])

# %%
y_test
# Out:
# 2     26100
# 5     26750
# 17    19700
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 0.6909238059446475
