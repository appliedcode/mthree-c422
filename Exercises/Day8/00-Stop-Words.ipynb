# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Stop Words
# Words like "a" and "the" appear so frequently that they don't require tagging as thoroughly as nouns, verbs and modifiers. We call these *stop words*, and they can be filtered from the text to be processed. spaCy holds a built-in list of some 305 English stop words.

# %%
# Perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Print the set of spaCy's default stop words (remember that sets are unordered):
print(nlp.Defaults.stop_words)
# Out:
# {'very', 'none', 'hence', 'between', 'beyond', 'yet', 'nothing', 'upon', 'before', 'it', 'whither', "'ll", 'who', '‘ll', 'besides', 'if', 'out', 'here', 'either', 'thence', 'more', 'becoming', 'whenever', 'even', 'afterwards', 'everything', 'why', 'n‘t', 'each', 'anyhow', '’s', 'enough', 'can', 'several', 'since', 'keep', 'formerly', 'among', 'her', 'should', 'never', 'just', 'sixty', 'bottom', "'d", 'perhaps', 'meanwhile', 'first', 'thereupon', 'some', 'seemed', 'would', 'that', 'thereby', 'call', 'whereby', 'least', 'else', 'beside', 'see', 'do', 'please', 'cannot', 'from', 'itself', 'thus', 'in', 'often', 'ten', '‘re', 'the', 'until', 'am', 'give', 'he', 'we', 'ourselves', 'many', 'now', 'while', 'except', 'though', 'less', 'much', '’d', 'over', 'themselves', 'part', 'yourself', 'will', 'herein', 'side', 'one', 'than', 'nor', 'few', 'then', 'always', 'as', 'through', 'us', 'hereby', 'without', 'three', 'below', 'whether', 'with', 'seeming', 'hers', 'seem', 'be', 'been', 'really', 'his', 'third', 'mine', 'because', "n't", 'per', 'serious', 'whole', 'at', 'became', 'of', 'indeed', 'whose', 'along', 'nowhere', 'eleven', 'my', 'onto', 'something', 'whereas', 'used', 'noone', 'most', 'neither', 're', 'again', 'also', 'same', 'show', 'although', 'toward', 'further', 'may', 'still', 'which', "'s", 'using', 'become', 'is', 'about', 'could', 'on', 'seems', 'whereafter', 'this', '’ve', 'beforehand', 'off', 'or', 'an', 'other', 'how', 'you', '‘s', '‘ve', 'hereafter', 'must', 'but', 'anyone', 'throughout', 'were', 'a', 'put', 'almost', 'into', 'once', 'me', 'twenty', 'twelve', 'was', 'already', 'what', 'no', 'nobody', 'somehow', 'nevertheless', 'around', 'full', 'last', 'all', 'might', 'i', 'hereupon', 'elsewhere', 'six', 'has', 'thru', '‘d', 'anyway', 'does', 'did', 'everywhere', 'after', 'five', 'therein', 'their', 'empty', 'former', 'for', 'another', 'and', 'yours', '‘m', 'ours', 'becomes', 'by', "'ve", 'behind', 'fifty', 'whom', 'these', 'moreover', 'when', 'down', 'latter', 'whoever', 'against', 'whence', 'there', 'two', 'various', 'get', 'made', 'hundred', 'sometimes', 'unless', 'namely', 'our', 'whatever', 'those', "'m", 'eight', 'under', 'its', 'own', 'well', 'myself', 'name', 'move', 'so', 'yourselves', 'somewhere', 'everyone', 'go', 'them', 'towards', 'front', 'such', 'latterly', 'any', 'via', 'ca', 'back', 'someone', 'therefore', 'n’t', 'forty', 'rather', 'together', 'both', '’re', 'mostly', 'himself', 'have', 'due', 'however', 'top', 'every', 'alone', 'thereafter', 'are', "'re", 'otherwise', 'say', 'him', 'too', 'others', 'within', 'up', 'where', 'done', 'amongst', 'doing', 'amount', 'across', 'wherever', 'being', 'nine', 'make', 'they', 'herself', 'not', 'during', 'fifteen', 'ever', 'whereupon', 'wherein', 'only', 'four', 'next', 'anywhere', 'your', 'to', 'she', 'sometime', '’m', 'had', 'take', 'anything', '’ll', 'quite', 'regarding', 'above'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %% [markdown]
# ## To see if a word is a stop word

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %% [markdown]
# ## To add a stop word
# There may be times when you wish to add a stop word to the default set. Perhaps you decide that `'btw'` (common shorthand for "by the way") should be considered a stop word.

# %%
# Add the word to the set of stop words. Use lowercase!
nlp.Defaults.stop_words.add('btw')

# Set the stop_word tag on the lexeme
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %% [markdown]
# <font color=green>When adding stop words, always use lowercase. Lexemes are converted to lowercase before being added to **vocab**.</font>

# %% [markdown]
# ## To remove a stop word
# Alternatively, you may decide that `'beyond'` should not be considered a stop word.

# %%
# Remove the word from the set of stop words
nlp.Defaults.stop_words.remove('beyond')

# Remove the stop_word tag from the lexeme
nlp.vocab['beyond'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False

# %% [markdown]
# Great! Now you should be able to access spaCy's default set of stop words, and add or remove stop words as needed.
# ## Next up: Vocabulary and Matching
