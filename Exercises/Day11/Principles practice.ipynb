# %% [markdown]
# <a href="https://colab.research.google.com/github/appliedcode/mthree-c422/blob/main/Exercises/day-11/Prompt-principles/Principles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📓 **Colab Lab: Practicing the 5 Principles of Prompt Engineering with GPT‑4o-mini**

# %%
# Setup
# Install OpenAI SDK
# !pip install openai -q
from google.colab import userdata
import os

openai_api_key = userdata.get("OPENAI_API_KEY")
if openai_api_key:
    os.environ["OPENAI_API_KEY"] = openai_api_key
    print("✅ OpenAI API key loaded safely")
else:
    print("❌ OpenAI API key not found. Please set it using Colab Secrets.")
# Out:
# ✅ OpenAI API key loaded safely

# %%
from openai import OpenAI
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])  # Replace with your API key

def ask_gpt(prompt, temp=0.7, max_tokens=500):
    """Send a prompt to GPT-4o-mini and return the output"""
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=temp,
        max_tokens=max_tokens
    )
    return response.choices[0].message.content

# %% [markdown]
# ## **Principle 1 — Give Clear Direction**
#
# **Goal:** Be specific about *what*, *for whom*, and *how* the task should be done.

# %%
prompt = "Write a 50-word friendly welcome message for first-year university students in an encouraging tone."
print(ask_gpt(prompt))
# Out:
# Welcome, first-year students! 🎉 We're thrilled to have you join our vibrant campus community. Embrace this exciting journey of learning, growth, and friendship. Remember, every challenge is an opportunity, and you’re not alone—your fellow students and faculty are here to support you. Here’s to an amazing year ahead! 🌟

# %%
# TODO: Your prompt here
vague_prompt = "Write about energy."
clear_prompt = "Explain renewable energy sources (solar, wind, hydropower) to high school students in an informative but simple tone, 100 words or less."

print("Vague Output:\n", ask_gpt(vague_prompt))
print("\nClear Output:\n", ask_gpt(clear_prompt))
# Out:
# Vague Output:
#  Energy is a fundamental concept in physics and everyday life, representing the capacity to do work or produce change. It exists in various forms, including kinetic energy (the energy of motion), potential energy (stored energy based on position), thermal energy (related to temperature), chemical energy (stored in chemical bonds), and nuclear energy (released during nuclear reactions).
#
# ### Forms of Energy
#
# 1. **Kinetic Energy**: This is the energy of moving objects. The kinetic energy of an object depends on its mass and velocity and is calculated using the formula:
#    \[
#    KE = \frac{1}{2} mv^2
#    \]
#    where \( m \) is the mass and \( v \) is the velocity.
#
# 2. **Potential Energy**: This energy is stored due to an object's position or state. For example, gravitational potential energy is related to an object's height above the ground and is calculated using:
#    \[
#    PE = mgh
#    \]
#    where \( m \) is mass, \( g \) is the acceleration due to gravity, and \( h \) is height.
#
# 3. **Thermal Energy**: This form of energy is associated with the temperature of an object. It arises from the kinetic energy of atoms and molecules; the faster they move, the more thermal energy they possess.
#
# 4. **Chemical Energy**: Found in the bonds of chemical compounds, this energy is released or absorbed during a chemical reaction. For instance, when fuels like coal or gasoline burn, they release energy that can be harnessed for work.
#
# 5. **Nuclear Energy**: This energy is stored in the nucleus of atoms and can be released during nuclear fission or fusion. Nuclear power plants utilize fission reactions to generate electricity.
#
# ### Conservation of Energy
#
# One of the most important principles regarding energy is the law of conservation of energy, which states that energy cannot be created or destroyed, only transformed from one form to another. This principle underpins many physical processes and is crucial for understanding energy flows in ecosystems, machines, and the universe at large.
#
# ### Energy Sources
#
# Energy can be sourced from two main categories:
#
# 1. **Renewable Energy**: These sources are replenished naturally and include solar power, wind energy, hydroelectric power, geothermal energy, and biomass. They are considered more sustainable as they have a lower environmental impact and can mitigate climate change.
#
# 2. **Non-Renewable Energy**: These sources, such
#
# Clear Output:
#  Renewable energy sources are natural ways to generate power that won't run out.
#
# 1. **Solar energy** harnesses sunlight using solar panels to produce electricity or heat.
#
# 2. **Wind energy** captures the power of the wind with turbines that spin to generate electricity.
#
# 3. **Hydropower** uses flowing water, usually from rivers or dams, to turn turbines and create energy.
#
# These sources are clean and sustainable, meaning they help reduce pollution and combat climate change, making them essential for a greener future!

# %% [markdown]
# ## **Principle 2 — Specify Format**
#
# **Goal:** Tell the AI exactly how to structure its response.

# %%
para_prompt = "Compare Phone A, Phone B, and Phone C."
table_prompt = "Compare Phone A, Phone B, and Phone C in a markdown table with columns: Phone, Display, Camera, Battery."

print("Paragraph Output:\n", ask_gpt(para_prompt))
print("\nTable Output:\n", ask_gpt(table_prompt))
# Out:
# Paragraph Output:
#  To provide a comparison of Phone A, Phone B, and Phone C, I would need specific details about each phone, such as:
#
# 1. **Brand and Model**: What are the specific models of the phones?
# 2. **Specifications**: Key specs like processor, RAM, storage options, camera quality, battery capacity, display type and size, etc.
# 3. **Operating System**: What OS do they run (e.g., Android, iOS)?
# 4. **Features**: Special features such as 5G support, waterproofing, unique camera capabilities, etc.
# 5. **Price**: What is the price range for each phone?
# 6. **Target Audience**: Are they aimed at budget, mid-range, or flagship consumers?
# 7. **User Reviews**: Any notable feedback or ratings from users?
#
# With this information, I can provide a detailed comparison. Please provide the details or the specific features you want to compare!
#
# Table Output:
#  Here's a markdown table comparing Phone A, Phone B, and Phone C based on their display, camera, and battery specifications:
#
# ```markdown
# | Phone   | Display              | Camera                 | Battery        |
# |---------|----------------------|------------------------|----------------|
# | Phone A | 6.1-inch OLED, 1080x2400 | 12 MP (wide) + 12 MP (ultrawide) | 4000 mAh       |
# | Phone B | 6.5-inch LCD, 720x1600 | 48 MP (wide)          | 5000 mAh       |
# | Phone C | 6.7-inch AMOLED, 1440x3120 | 108 MP (wide) + 12 MP (ultrawide) + 5 MP (macro) | 4500 mAh       |
# ```
#
# Feel free to modify the specifications according to the actual details of the phones you have in mind!

# %% [markdown]
# ## **Principle 3 — Provide Examples (Few-Shot Prompting)**
#
# **Goal:** Show the AI what kind of response you expect.

# %% [markdown]
# **🎯 Student Exercise:**
#
# - Create a **few-shot prompt** to classify movie reviews as "Positive", "Negative", "Neutral". Provide at least 2 examples for each label, then add a new review for the model to classify.

# %%
few_shot_prompt = """
Classify each review as Positive, Negative, or Neutral:

Review: "Loved the espresso, very rich flavor."
Sentiment: Positive

Review: "Service was slow but the ambiance was nice."
Sentiment: Neutral

Review: "The croissant was stale and dry."
Sentiment: Negative

Review: "Great coffee but a bit noisy during peak hours."
Sentiment:
"""

print(ask_gpt(few_shot_prompt))
# Out:
# Sentiment: Neutral

# %% [markdown]
# ## **Principle 4 — Evaluate Quality**
#
# **Goal:** Review the AI output and refine the prompt to improve quality.

# %%
text = """Community gardens are flourishing in cities worldwide, providing fresh produce and green spaces for residents. They improve air quality, foster social connections, and promote sustainability."""
# Initial vague prompt
vague_sum = ask_gpt(f"Summarize this text: {text}")

# Improved prompt
refined_sum = ask_gpt(f"Summarize this article in 3 bullet points each covering: 1) Main benefits 2) Social impact 3) Environmental effects : {text}")

print("Original Summary:\n", vague_sum)
print("\nRefined Summary:\n", refined_sum)
# Out:
# Original Summary:
#  Community gardens are thriving globally, offering fresh produce and green spaces while enhancing air quality, fostering social connections, and promoting sustainability.
#
# Refined Summary:
#  - **Main Benefits**: Community gardens offer access to fresh produce, enhance local food security, and provide green spaces that contribute to overall well-being and health for urban residents.
#
# - **Social Impact**: These gardens foster social connections among community members, encouraging collaboration, cultural exchange, and a sense of belonging within diverse neighborhoods.
#
# - **Environmental Effects**: Community gardens improve air quality, promote biodiversity, and support sustainable practices by encouraging local food production and reducing urban heat islands.

# %% [markdown]
# ## **Principle 5 — Divide Labor (Break Down Complex Tasks)**

# %%
# Step 1
audience_analysis = ask_gpt("Describe the target audience for an online bookstore focused on rare and antique books.")
# Step 2
social_media_strategy = ask_gpt("Based on the above audience, create a marketing strategy with 5 bullet points.")
# Step 3
content_calendar = ask_gpt("Propose a 1-month social media content calendar in a table with Date, Post Idea, and Caption.")

print("Audience Analysis:\n", audience_analysis)
print("\nSocial Media Strategy:\n", social_media_strategy)
print("\nContent Calendar:\n", content_calendar)
# Out:
# Audience Analysis:
#  The target audience for an online bookstore specializing in rare and antique books can be characterized by several key demographics and psychographics:
#
# 1. **Book Collectors and Enthusiasts**: This group includes avid readers and collectors who have a passion for unique, rare, or historical texts. They may be looking for specific editions, first prints, or books with historical significance.
#
# 2. **Academics and Researchers**: Scholars, historians, and students may seek rare books for research purposes, including primary sources for academic work. They often appreciate the provenance and scholarly value of antique texts.
#
# 3. **Gift Buyers**: Individuals looking for unique, meaningful gifts for friends or family members who appreciate literature or history may be drawn to rare books. This audience often seeks special editions or beautifully bound volumes.
#
# 4. **Investors and Speculators**: Some customers view rare books as alternative investments, seeking to buy and resell them for profit. They are typically knowledgeable about the market and trends in book value.
#
# 5. **History Buffs and Culture Enthusiasts**: Individuals with a passion for history, art, and culture may be interested in rare books that reflect specific historical periods or movements. They appreciate the cultural and aesthetic value of antique books.
#
# 6. **Libraries and Institutions**: Public and private libraries, universities, and museums may seek rare books to enhance their collections. This audience often has specific criteria and budgets for acquisitions.
#
# 7. **Literary Aficionados**: People who have a deep appreciation for literature and its history are likely to be interested in rare editions of classic works, author-signed copies, or books with unique literary significance.
#
# 8. **Age and Income Demographics**: The target audience may skew towards older adults, as they are more likely to have the disposable income and interest in investing in rare books. However, younger collectors and enthusiasts are also emerging, particularly those with an interest in vintage aesthetics and sustainability.
#
# 9. **Online Savvy Consumers**: The audience is likely to be comfortable with online shopping and may appreciate a well-designed website that offers detailed descriptions, high-quality images, and clear provenance information about the books.
#
# 10. **Global Reach**: Since rare books can attract collectors from around the world, the audience may be international, requiring the bookstore to consider shipping logistics and regional interests.
#
# By understanding these characteristics, an online bookstore focused on rare and antique books can tailor its marketing strategies, inventory selection, and customer engagement efforts to effectively reach and serve its
#
# Social Media Strategy:
#  To create an effective marketing strategy tailored to your audience, consider the following five bullet points:
#
# 1. **Targeted Content Creation**: Develop high-quality, relevant content that addresses the specific interests and pain points of your audience. Utilize blogs, videos, and infographics to educate and engage, establishing your brand as a trusted authority in your industry.
#
# 2. **Social Media Engagement**: Utilize platforms where your audience is most active to foster community engagement. Implement interactive campaigns, such as polls, Q&As, and live sessions, to build relationships and encourage user-generated content.
#
# 3. **Personalized Email Marketing**: Segment your audience based on demographics, behaviors, and preferences to deliver tailored email campaigns. Use personalized messaging and exclusive offers to increase open rates and conversions.
#
# 4. **Influencer Collaborations**: Partner with influencers who resonate with your target audience to enhance brand credibility and reach. Leverage their platforms for authentic endorsements and co-created content that aligns with your brand values.
#
# 5. **Data-Driven Analytics**: Regularly analyze performance metrics to understand audience behavior and preferences. Use insights to refine your strategy, optimize campaigns in real-time, and ensure alignment with your audience's evolving needs and interests.
#
# These strategies can help you effectively engage your audience, drive brand awareness, and boost conversions.
#
# Content Calendar:
#  Here's a 1-month social media content calendar designed for a fictitious brand, "EcoVibe," which focuses on sustainable living and eco-friendly products. You can adjust the themes and ideas according to your brand's niche.
#
# | Date       | Post Idea                                    | Caption                                                  |
# |------------|----------------------------------------------|---------------------------------------------------------|
# | 1st        | Introduction to EcoVibe                     | "🌍 Welcome to EcoVibe! Join us on our journey towards a sustainable future. Together, we can make a difference! #EcoVibe #SustainableLiving" |
# | 3rd        | Product Spotlight: Reusable Bags             | "Say goodbye to single-use plastic! 🌱 Our eco-friendly reusable bags are perfect for all your shopping needs. #EcoVibe #ReusableBags" |
# | 5th        | Sustainable Living Tip                       | "Tip Tuesday! 🌿 Did you know that reducing meat consumption can lower your carbon footprint? Try going meatless one day a week! #SustainableTip #EcoVibe" |
# | 7th        | Customer Testimonial                         | "🌟 Hear from our amazing customers! 'EcoVibe has completely transformed my shopping habits. Love their products!' - Sarah M. #CustomerLove #EcoVibe" |
# | 10th       | Behind-the-Scenes: Product Creation         | "Ever wonder how our products are made? 🤔 Step behind the scenes with us to see the eco-friendly process! #BehindTheScenes #EcoVibe" |
# | 12th       | Eco-Friendly DIY Project                     | "Get crafty with this easy DIY project! 🌸 Turn old jars into beautiful planters. Share your creations with us! #DIYEco #EcoVibe" |
# | 15th       | Poll: Favorite Eco-Friendly Product         | "🗳️ We want to hear from you! What's your favorite EcoVibe product? Vote in our poll and let us know! #EcoPoll #EcoVibe" |
# | 17th       | Infographic: Benefits of Sustainable Living  | "Why choose sustainable living? 🌎 Check out these amazing benefits! #SustainableLiving #EcoVibe" |
# | 20th       | Giveaway Announcement                         | "🎉 GIVEAWAY TIME! 🎉 Win a bundle of our favorite eco-friendly products! Tag a friend to enter! #EcoVibeGiveaway" |
# | 22nd       | Fun Fact about Recycling

# %% [markdown]
# ## **💡 Reflection Questions for Students**
#
# - Which principle improved your results the most?
# - Did specifying format make the output easier to use?
# - How did providing examples change the output?
# - When would breaking down a task be most useful?
