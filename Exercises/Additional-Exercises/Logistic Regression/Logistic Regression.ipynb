# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.figure(figsize = (5,4))
plt.scatter(df['age'], df['bought_insurance'] )

# %%
from sklearn.model_selection import train_test_split
X = df[['age']]
y = df['bought_insurance']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1], dtype=int64)

# %%
y_test
# Out:
# 5     1
# 18    0
# 2     1
# Name: bought_insurance, dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.11182153, 0.88817847],
#        [0.93050057, 0.06949943],
#        [0.28148003, 0.71851997]])

# %%
model.predict([[25]]), model.predict([[53]])
# Out:
# D:\Anaconda__\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# D:\Anaconda__\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# (array([0], dtype=int64), array([1], dtype=int64))
