# %%
import pandas as pd
from sklearn.datasets import load_wine
wine = load_wine()
dir(wine)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
df = pd.DataFrame(wine.data, columns = wine.feature_names)
df['target'] = wine.target
df.sample(10)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 59     12.37        0.94  1.36               10.6       88.0           1.98
# 71     13.86        1.51  2.67               25.0       86.0           2.95
# 81     12.72        1.81  2.20               18.8       86.0           2.20
# 100    12.08        2.08  1.70               17.5       97.0           2.23
# 94     11.62        1.99  2.28               18.0       98.0           3.02
# 99     12.29        3.17  2.21               18.0       88.0           2.85
# 27     13.30        1.72  2.14               17.0       94.0           2.40
# 11     14.12        1.48  2.32               16.8       95.0           2.20
# 133    12.70        3.55  2.36               21.5      106.0           1.70
# 103    11.82        1.72  1.88               19.5       86.0           2.50
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 59         0.57                  0.28             0.42             1.95  1.05
# 71         2.86                  0.21             1.87             3.38  1.36
# 81         2.53                  0.26             1.77             3.90  1.16
# 100        2.17                  0.26             1.40             3.30  1.27
# 94         2.26                  0.17             1.35             3.25  1.16
# 99         2.99                  0.45             2.81             2.30  1.42
# 27         2.19                  0.27             1.35             3.95  1.02
# 11         2.43                  0.26             1.57             5.00  1.17
# 133        1.20                  0.17             0.84             5.00  0.78
# 103        1.64                  0.37             1.42             2.06  0.94
#
#      od280/od315_of_diluted_wines  proline  target
# 59                           1.82    520.0       1
# 71                           3.16    410.0       1
# 81                           3.14    714.0       1
# 100                          2.96    710.0       1
# 94                           2.96    345.0       1
# 99                           2.83    406.0       1
# 27                           2.77   1285.0       0
# 11                           2.82   1280.0       0
# 133                          1.29    600.0       2
# 103                          2.44    415.0       1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['alcohol'].plot(kind='hist', bins=20, title='alcohol')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['malic_acid'].plot(kind='hist', bins=20, title='malic_acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['ash'].plot(kind='hist', bins=20, title='ash')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['alcalinity_of_ash'].plot(kind='hist', bins=20, title='alcalinity_of_ash')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='alcohol', y='malic_acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='malic_acid', y='ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='ash', y='alcalinity_of_ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='alcalinity_of_ash', y='magnesium', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['alcohol'].plot(kind='line', figsize=(8, 4), title='alcohol')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['malic_acid'].plot(kind='line', figsize=(8, 4), title='malic_acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['ash'].plot(kind='line', figsize=(8, 4), title='ash')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['alcalinity_of_ash'].plot(kind='line', figsize=(8, 4), title='alcalinity_of_ash')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
y = df['target']
X = df.drop(['target'], axis = 1)
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['alcohol'].plot(kind='hist', bins=20, title='alcohol')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['malic_acid'].plot(kind='hist', bins=20, title='malic_acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['ash'].plot(kind='hist', bins=20, title='ash')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['alcalinity_of_ash'].plot(kind='hist', bins=20, title='alcalinity_of_ash')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16.plot(kind='scatter', x='alcohol', y='malic_acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='malic_acid', y='ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='ash', y='alcalinity_of_ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='alcalinity_of_ash', y='magnesium', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['alcohol'].plot(kind='line', figsize=(8, 4), title='alcohol')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['malic_acid'].plot(kind='line', figsize=(8, 4), title='malic_acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['ash'].plot(kind='line', figsize=(8, 4), title='ash')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['alcalinity_of_ash'].plot(kind='line', figsize=(8, 4), title='alcalinity_of_ash')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)
X = pd.DataFrame(X, columns = wine.feature_names)
X.head()
# Out:
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  0.842105    0.191700  0.572193           0.257732   0.619565
# 1  0.571053    0.205534  0.417112           0.030928   0.326087
# 2  0.560526    0.320158  0.700535           0.412371   0.336957
# 3  0.878947    0.239130  0.609626           0.319588   0.467391
# 4  0.581579    0.365613  0.807487           0.536082   0.521739
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0       0.627586    0.573840              0.283019         0.593060
# 1       0.575862    0.510549              0.245283         0.274448
# 2       0.627586    0.611814              0.320755         0.757098
# 3       0.989655    0.664557              0.207547         0.558360
# 4       0.627586    0.495781              0.490566         0.444795
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# 0         0.372014  0.455285                      0.970696  0.561341
# 1         0.264505  0.463415                      0.780220  0.550642
# 2         0.375427  0.447154                      0.695971  0.646933
# 3         0.556314  0.308943                      0.798535  0.857347
# 4         0.259386  0.455285                      0.608059  0.325963
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_24['alcohol'].plot(kind='hist', bins=20, title='alcohol')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['malic_acid'].plot(kind='hist', bins=20, title='malic_acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['ash'].plot(kind='hist', bins=20, title='ash')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['alcalinity_of_ash'].plot(kind='hist', bins=20, title='alcalinity_of_ash')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='alcohol', y='malic_acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='malic_acid', y='ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='ash', y='alcalinity_of_ash', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_31.plot(kind='scatter', x='alcalinity_of_ash', y='magnesium', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_32['alcohol'].plot(kind='line', figsize=(8, 4), title='alcohol')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_33['malic_acid'].plot(kind='line', figsize=(8, 4), title='malic_acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_34['ash'].plot(kind='line', figsize=(8, 4), title='ash')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35['alcalinity_of_ash'].plot(kind='line', figsize=(8, 4), title='alcalinity_of_ash')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
gnb, mnb = GaussianNB(), MultinomialNB()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
gnb.fit(X_train, y_train)
gnb.score(X_test,y_test)
# Out:
# 0.9444444444444444

# %%
mnb.fit(X_train, y_train)
mnb.score(X_test, y_test)
# Out:
# 0.9444444444444444
